# %%
import pandas as pd 
import pandas_datareader as pdr
import matplotlib.pyplot as plt 
import seaborn as sns
from Finance import *

# %%
aapl = pdr.get_data_yahoo('AMZN', '2021-01-01')

# %%
aapl.head()
# Out:
#                    High          Low        Open        Close   Volume  \
# Date
# 2021-01-04  3272.000000  3144.020020  3270.00000  3186.629883  4411400
# 2021-01-05  3223.379883  3165.060059  3166.01001  3218.510010  2655500
# 2021-01-06  3197.510010  3131.159912  3146.47998  3138.379883  4394800
# 2021-01-07  3208.540039  3155.000000  3157.00000  3162.159912  3514500
# 2021-01-08  3190.639893  3142.199951  3180.00000  3182.699951  3537700
#
#               Adj Close
# Date
# 2021-01-04  3186.629883
# 2021-01-05  3218.510010
# 2021-01-06  3138.379883
# 2021-01-07  3162.159912
# 2021-01-08  3182.699951

# %%
plt.figure(figsize=(8,4), dpi=300)
plt.grid(True)
plt.plot(aapl.index, aapl['Adj Close'])

# %%
aapl['MA_200'] = aapl['Adj Close'].rolling(window =200).mean()
aapl['MA_50'] = aapl['Adj Close'].rolling(window =50).mean()
aapl['MA_20'] = aapl['Adj Close'].rolling(window =20).mean()

# %%
plt.figure(figsize=(8,4), dpi=300)
plt.grid(True)
plt.plot(aapl.index, aapl['Adj Close'])
plt.plot(aapl.index, aapl.MA_200)
plt.plot(aapl.index, aapl.MA_20)
plt.plot(aapl.index, aapl.MA_50)

# %%
aapl['Up_20BB'], aapl['Down_20BB'] = get_bollinger_bands(aapl['Adj Close'])

# %%
aapl
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2021-01-04  3272.000000  3144.020020  3270.000000  3186.629883  4411400
# 2021-01-05  3223.379883  3165.060059  3166.010010  3218.510010  2655500
# 2021-01-06  3197.510010  3131.159912  3146.479980  3138.379883  4394800
# 2021-01-07  3208.540039  3155.000000  3157.000000  3162.159912  3514500
# 2021-01-08  3190.639893  3142.199951  3180.000000  3182.699951  3537700
# ...                 ...          ...          ...          ...      ...
# 2022-02-07  3253.820068  3145.000000  3170.399902  3158.709961  5131200
# 2022-02-08  3235.850098  3111.010010  3135.010010  3228.270020  3802000
# 2022-02-09  3276.689941  3205.000000  3257.469971  3223.790039  3439300
# 2022-02-10  3214.330078  3155.000000  3167.000000  3180.070068  3413400
# 2022-02-11  3180.000000  3054.679932  3162.689941  3065.870117  3851600
#
#               Adj Close       MA_200        MA_50        MA_20      Up_20BB  \
# Date
# 2021-01-04  3186.629883          NaN          NaN          NaN          NaN
# 2021-01-05  3218.510010          NaN          NaN          NaN          NaN
# 2021-01-06  3138.379883          NaN          NaN          NaN          NaN
# 2021-01-07  3162.159912          NaN          NaN          NaN          NaN
# 2021-01-08  3182.699951          NaN          NaN          NaN          NaN
# ...                 ...          ...          ...          ...          ...
# 2022-02-07  3158.709961  3367.073304  3261.391216  3037.752002  3407.372610
# 2022-02-08  3228.270020  3366.169655  3255.865415  3037.679504  3407.142109
# 2022-02-09  3223.790039  3365.201455  3249.109814  3033.507007  3391.869807
# 2022-02-10  3180.070068  3363.809305  3242.569814  3027.303516  3369.888861
# 2022-02-11  3065.870117  3361.782106  3235.012817  3019.383020  3349.905849
#
#               Down_20BB
# Date
# 2021-01-04          NaN
# 2021-01-05          NaN
# 2021-01-06          NaN
# 2021-01-07          NaN
# 2021-01-08          NaN
# ...                 ...
# 2022-02-07  2668.131394
# 2022-02-08  2668.216899
# 2022-02-09  2675.144207
# 2022-02-10  2684.718170
# 2022-02-11  2688.860191
#
# [281 rows x 11 columns]

# %%
plt.figure(figsize=(8,4), dpi=300)
plt.grid(True)
plot_bollinger_bands(aapl['Adj Close'])

# %%
plot_bb_strategy(aapl['Adj Close'],aapl.Up_20BB, aapl.Down_20BB)

# %%
return_strategy(aapl['Adj Close'],aapl.Up_20BB, aapl.Down_20BB)
# Out:
#           Date    Adj Close      Up_20BB    Down_20BB  bb_signal  bb_position
# 0   2021-01-04  3186.629883          NaN          NaN          0            1
# 1   2021-01-05  3218.510010          NaN          NaN          0            1
# 2   2021-01-06  3138.379883          NaN          NaN          0            1
# 3   2021-01-07  3162.159912          NaN          NaN          0            1
# 4   2021-01-08  3182.699951          NaN          NaN          0            1
# ..         ...          ...          ...          ...        ...          ...
# 276 2022-02-07  3158.709961  3407.372610  2668.131394          0            1
# 277 2022-02-08  3228.270020  3407.142109  2668.216899          0            1
# 278 2022-02-09  3223.790039  3391.869807  2675.144207          0            1
# 279 2022-02-10  3180.070068  3369.888861  2684.718170          0            1
# 280 2022-02-11  3065.870117  3349.905849  2688.860191          0            1
#
# [281 rows x 6 columns]

# %%
backtest_strategy(aapl['Adj Close'],aapl.Up_20BB, aapl.Down_20BB)
# Out:
# Profit gained from the BB strategy by investing $100k: 12206.73
# Profit percentage of the BB strategy : 12%
